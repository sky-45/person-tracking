# %%
#paquetes generales
import os
#os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import cv2
import numpy as np
import tensorflow as tf
import time
#import yolov3
from yolov3.utils import Load_Yolo_model, image_preprocess, postprocess_boxes, nms, draw_bbox, read_class_names
from yolov3.configs import *
#import deepsort
from deep_sort import nn_matching
from deep_sort.detection import Detection
from deep_sort.tracker import Tracker
from deep_sort import generate_detections as gdet

# %%
video_path   = "test.mp4"
#video_path = False
def Object_tracking(Yolo, video_path, output_path, input_size=416, show=False, CLASSES=YOLO_COCO_CLASSES, 
                    score_threshold=0.3, iou_threshold=0.45, rectangle_colors='', Track_only = []):
    # Definition of the parameters
    max_cosine_distance = 0.7
    nn_budget = None
    
    #initialize deep sort object
    model_filename = 'model_data/mars-small128.pb'
    encoder = gdet.create_box_encoder(model_filename, batch_size=1)
    metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
    tracker = Tracker(metric)
    print("Model deep-sort cargado")
    times, times_2 = [], []

    if video_path:
        vid = cv2.VideoCapture(video_path) # detect on video
    else:
        vid = cv2.VideoCapture(0) # detect from webcam
    
    # by default VideoCapture returns float instead of int
    width = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(vid.get(cv2.CAP_PROP_FPS))
    codec = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_path, codec, fps, (width, height)) # output_path must be .mp4

    NUM_CLASS = read_class_names(CLASSES)
    key_list = list(NUM_CLASS.keys()) 
    val_list = list(NUM_CLASS.values())
    print("Iniciando captura de frames")
    while True:
        _, frame = vid.read()

        try:
            original_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            original_frame = cv2.cvtColor(original_frame, cv2.COLOR_BGR2RGB)
        except:
            break
        
        image_data = image_preprocess(np.copy(original_frame), [input_size, input_size])
        #image_data = tf.expand_dims(image_data, 0)
        image_data = image_data[np.newaxis, ...].astype(np.float32)

        t1 = time.time()
        if YOLO_FRAMEWORK == "tf":
            pred_bbox = Yolo.predict(image_data)
        elif YOLO_FRAMEWORK == "trt":
            batched_input = tf.constant(image_data)
            result = Yolo(batched_input)
            pred_bbox = []
            for key, value in result.items():
                value = value.numpy()
                pred_bbox.append(value)
        
        #t1 = time.time()
        #pred_bbox = Yolo.predict(image_data)
        t2 = time.time()
        
        pred_bbox = [tf.reshape(x, (-1, tf.shape(x)[-1])) for x in pred_bbox]
        pred_bbox = tf.concat(pred_bbox, axis=0)

        bboxes = postprocess_boxes(pred_bbox, original_frame, input_size, score_threshold)
        bboxes = nms(bboxes, iou_threshold, method='nms')

        # extract bboxes to boxes (x, y, width, height), scores and names
        boxes, scores, names = [], [], []
        for bbox in bboxes:
            if len(Track_only) !=0 and NUM_CLASS[int(bbox[5])] in Track_only or len(Track_only) == 0:
                boxes.append([bbox[0].astype(int), bbox[1].astype(int), bbox[2].astype(int)-bbox[0].astype(int), bbox[3].astype(int)-bbox[1].astype(int)])
                scores.append(bbox[4])
                names.append(NUM_CLASS[int(bbox[5])])

        # Obtain all the detections for the given frame.
        boxes = np.array(boxes) 
        names = np.array(names)
        scores = np.array(scores)
        features = np.array(encoder(original_frame, boxes))
        detections = [Detection(bbox, score, class_name, feature) for bbox, score, class_name, feature in zip(boxes, scores, names, features)]

        # Pass detections to the deepsort object and obtain the track information.
        tracker.predict()
        tracker.update(detections)

        # Obtain info from the tracks
        tracked_bboxes = []
        for track in tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 5:
                continue 
            bbox = track.to_tlbr() # Get the corrected/predicted bounding box
            class_name = track.get_class() #Get the class name of particular object
            tracking_id = track.track_id # Get the ID for the particular track
            index = key_list[val_list.index(class_name)] # Get predicted object index by object name
            tracked_bboxes.append(bbox.tolist() + [tracking_id, index]) # Structure data, that we could use it with our draw_bbox function
        
        # draw detection on frame
        image = draw_bbox(original_frame, tracked_bboxes, CLASSES=CLASSES, tracking=True)

        t3 = time.time()
        times.append(t2-t1)
        times_2.append(t3-t1)
        
        times = times[-20:]
        times_2 = times_2[-20:]

        ms = sum(times)/len(times)*1000
        fps = 1000 / ms
        fps2 = 1000 / (sum(times_2)/len(times_2)*1000)
        
        image = cv2.putText(image, "Time: {:.1f} FPS".format(fps), (0, 30), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 255), 2)

        # draw original yolo detection
        #image = draw_bbox(image, bboxes, CLASSES=CLASSES, show_label=False, rectangle_colors=rectangle_colors, tracking=True)

        print("Time: {:.2f}ms, Detection FPS: {:.1f}, total FPS: {:.1f}".format(ms, fps, fps2))
        if output_path != '': out.write(image)
        if show:
            cv2.imshow('output', image)
            
            if cv2.waitKey(25) & 0xFF == ord("q"):
                cv2.destroyAllWindows()
                break
            
    cv2.destroyAllWindows()


yolo = Load_Yolo_model()
Object_tracking(yolo, video_path, "track.mp4", input_size=YOLO_INPUT_SIZE, show=True, 
                iou_threshold=0.1, rectangle_colors=(255,0,0), Track_only = ["person"])
# Out:
# GPUs [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Model deep-sort cargado
# Iniciando captura de frames
# Time: 11210.40ms, Detection FPS: 0.1, total FPS: 0.1
# Time: 5967.29ms, Detection FPS: 0.2, total FPS: 0.1
# Time: 4219.81ms, Detection FPS: 0.2, total FPS: 0.2
# Time: 3323.73ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 2773.21ms, Detection FPS: 0.4, total FPS: 0.3
# Time: 2411.40ms, Detection FPS: 0.4, total FPS: 0.4
# Time: 2162.38ms, Detection FPS: 0.5, total FPS: 0.4
# Time: 1970.02ms, Detection FPS: 0.5, total FPS: 0.4
# Time: 1819.87ms, Detection FPS: 0.5, total FPS: 0.5
# Time: 1699.05ms, Detection FPS: 0.6, total FPS: 0.5
# Time: 1592.96ms, Detection FPS: 0.6, total FPS: 0.5
# Time: 1512.53ms, Detection FPS: 0.7, total FPS: 0.6
# Time: 1455.67ms, Detection FPS: 0.7, total FPS: 0.6
# Time: 1394.99ms, Detection FPS: 0.7, total FPS: 0.6
# Time: 1344.46ms, Detection FPS: 0.7, total FPS: 0.6
# Time: 1299.91ms, Detection FPS: 0.8, total FPS: 0.6
# Time: 1259.79ms, Detection FPS: 0.8, total FPS: 0.7
# Time: 1223.67ms, Detection FPS: 0.8, total FPS: 0.7
# Time: 1188.53ms, Detection FPS: 0.8, total FPS: 0.7
# Time: 1159.06ms, Detection FPS: 0.9, total FPS: 0.7
# Time: 628.68ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 624.73ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 619.54ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 610.69ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 611.40ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 612.08ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 606.24ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 609.69ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 608.18ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 608.75ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 613.74ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 618.51ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 611.55ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 612.50ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 611.36ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 610.43ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 611.41ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 608.44ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 610.98ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 612.06ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 618.71ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 613.94ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 613.92ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 621.70ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 624.17ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 631.85ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 635.80ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 631.94ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 634.32ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 639.09ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.06ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 632.88ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 632.41ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 627.35ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 623.31ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 620.36ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 624.54ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 633.32ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 640.35ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 640.78ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.38ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 642.17ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 635.17ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 639.94ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 633.09ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 623.01ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 623.35ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 620.82ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 621.45ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 616.15ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 621.71ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 622.31ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 622.52ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 625.12ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 622.33ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 631.49ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 625.71ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 621.03ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 608.89ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 604.76ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 600.32ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 599.94ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 609.09ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 606.04ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 613.19ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 616.41ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 613.42ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 618.76ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 618.46ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 619.70ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 616.17ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 616.20ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 615.73ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 619.22ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 626.79ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 625.15ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 620.41ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 620.40ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 626.73ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 631.52ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 633.87ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 634.70ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 632.40ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 631.87ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 633.29ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 634.23ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 637.13ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.38ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.35ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.68ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 634.01ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 636.83ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.79ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 644.23ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 648.52ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 643.90ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 653.54ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 655.07ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 655.34ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 656.51ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 649.34ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 650.72ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 653.61ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 653.34ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 650.77ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 650.69ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 650.14ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 647.61ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 647.01ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 647.09ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 650.55ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 645.26ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 644.13ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 640.83ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 635.71ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 636.39ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 633.05ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 630.88ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 630.22ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 628.40ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 634.29ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 633.22ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 632.81ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 632.06ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 636.47ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 637.04ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.22ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 634.20ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 636.10ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 634.12ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 667.14ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 675.77ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 673.88ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 671.51ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 674.62ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 670.07ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 665.93ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 667.18ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 663.78ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 663.55ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 663.65ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 662.36ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 660.40ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 661.45ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 657.83ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 656.97ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 655.41ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 654.31ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 646.67ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 644.05ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 610.89ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 603.97ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 604.48ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 603.70ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 601.60ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 607.05ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 611.14ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 610.82ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 608.37ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 607.40ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 608.08ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 604.48ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 603.82ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 606.06ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 607.80ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 607.63ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 608.22ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 614.07ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 620.74ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 625.52ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 624.68ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 625.18ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 626.30ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 627.40ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 627.02ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 627.12ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 626.42ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 623.42ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 624.91ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 625.81ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 625.37ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 630.59ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 632.08ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 630.87ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 628.80ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 628.49ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 629.37ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 628.56ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 627.77ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 627.04ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 628.88ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 629.63ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 629.01ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.01ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 625.39ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 626.40ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 626.68ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 623.59ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 628.54ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 628.02ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 631.58ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 625.91ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 625.84ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 625.26ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 625.95ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 627.15ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 625.99ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 628.86ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.71ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.00ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 628.77ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.02ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 630.55ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 631.04ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 636.36ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 635.97ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 636.84ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 639.13ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 636.01ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 636.56ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 637.95ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.55ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 643.04ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 644.47ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 643.40ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 647.23ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 647.95ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 645.19ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 647.54ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 648.99ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 648.24ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 646.72ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 646.42ms, Detection FPS: 1.5, total FPS: 1.3
# Time: 642.48ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 637.23ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 635.59ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 635.52ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.72ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 641.74ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 642.62ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.10ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 642.84ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 641.07ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.95ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 639.66ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 634.68ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 635.27ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 635.06ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 632.39ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 631.99ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 633.05ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 632.36ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 634.81ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 632.43ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 635.54ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 636.60ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 637.01ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.35ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 638.77ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 639.54ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 639.77ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 639.74ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 636.39ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 630.53ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.44ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.37ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.51ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.64ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.94ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.94ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.99ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 630.81ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 627.84ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 632.87ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 633.81ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 628.90ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 629.65ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 621.57ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 619.37ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 618.12ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 617.82ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 617.29ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 617.10ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 623.38ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 624.79ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 625.24ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 624.47ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 623.60ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 615.22ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 611.42ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 605.80ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 607.06ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 599.87ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 595.43ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 595.93ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 599.64ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 597.27ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 598.07ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 616.92ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 616.92ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 610.84ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 607.47ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 608.58ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 607.40ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 604.05ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 604.56ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 601.19ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 603.20ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 610.47ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 613.22ms, Detection FPS: 1.6, total FPS: 1.4
# Time: 618.21ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 617.04ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 621.82ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 620.76ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 614.49ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 616.66ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 616.67ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 619.19ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 602.27ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 601.63ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 600.83ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 605.64ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 599.66ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 596.31ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 596.40ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 596.43ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 596.10ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 594.49ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 594.18ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 587.83ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 588.14ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 590.55ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 591.88ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 594.22ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 600.16ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 595.18ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 594.43ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 598.75ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 597.76ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 594.24ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 597.36ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 595.46ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 595.59ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 597.44ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 598.36ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 594.75ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 595.82ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 590.02ms, Detection FPS: 1.7, total FPS: 1.4
# Time: 590.55ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 597.39ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 601.02ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 595.52ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 593.05ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 592.79ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 588.84ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 596.25ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 593.85ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 592.40ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 588.83ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 589.96ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 587.38ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 589.83ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 586.78ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 588.53ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 589.61ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 592.95ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 592.33ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 600.44ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 597.75ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 590.56ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 586.46ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 587.72ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 594.83ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 600.38ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 604.01ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 603.76ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 603.78ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 607.58ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 605.39ms, Detection FPS: 1.7, total FPS: 1.3
# Time: 611.03ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 620.99ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 615.50ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 626.39ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 624.91ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 619.73ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 620.57ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 617.98ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 611.30ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 610.14ms, Detection FPS: 1.6, total FPS: 1.3
# Time: 622.71ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 632.39ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 638.82ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 638.59ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 640.04ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 639.72ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 636.63ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 645.25ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 646.85ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 655.24ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 652.80ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 644.10ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 643.75ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 637.53ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 644.01ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 651.85ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 645.29ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 648.77ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 645.04ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 650.72ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 648.90ms, Detection FPS: 1.5, total FPS: 1.2
# Time: 641.54ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 632.83ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 630.45ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 629.03ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 626.93ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 627.37ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 622.37ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 618.30ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 620.86ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 625.37ms, Detection FPS: 1.6, total FPS: 1.2
# Time: 650.09ms, Detection FPS: 1.5, total FPS: 1.1
# Time: 649.38ms, Detection FPS: 1.5, total FPS: 1.1
# Time: 648.76ms, Detection FPS: 1.5, total FPS: 1.1
